# %% [markdown]
# **Animate a Scatterplot**
#
# In this exercise we will reproduce Hans Roslings famous animation. We will proceed in four steps:
#
# Load the data to multiple DataFrames
#
# Merge the DataFrames into one
#
# Generate one scatterplot for each year.
#
# Connect the images to an animated GIF.

# %%
###Step 1
###Load the file data/gapminder_total_fertility.csv into pandas.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

fert = pd.read_csv('/Users/JoseMontero/Desktop/gapminder_total_fertility.csv', index_col=0)

fert
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# ...                     ...   ...   ...   ...   ...   ...   ...   ...   ...
# Yugoslavia              NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Zambia                 6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71
# Zimbabwe               6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Åland                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
###Step 2
#Proceed in the same way with the file data/gapminder_lifeexpectancy.xlsx. Save it in a DataFrame with the name life.
#You need the function `pd.read_excel`.

life = pd.read_excel('/Users/JoseMontero/Desktop/gapminder_lifeexpectancy.xlsx', index_col=0)

life
# Out:
#                         1800   1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.20  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                35.40  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# Algeria                28.82  28.82  28.82  28.82  28.82  28.82  28.82  28.82
# ...                      ...    ...    ...    ...    ...    ...    ...    ...
# Yugoslavia               NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Zambia                 32.60  32.60  32.60  32.60  32.60  32.60  32.60  32.60
# Zimbabwe               33.70  33.70  33.70  33.70  33.70  33.70  33.70  33.70
# Åland                    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# South Sudan            26.67  26.67  26.67  26.67  26.67  26.67  26.67  26.67
#
# ...

# %%
fert.set_index('total fertility rate')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-5d607d1c520c> in <module>
# ----> 1 fert.set_index('total fertility rate')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['total fertility rate'] are in the columns"

# %%
#adding also population
popu = pd.read_excel('/Users/JoseMontero/Desktop/gapminder_population.xlsx', index_col=0)
popu
# Out:
#                                                    1800       1810       1820  \
# Total population
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3280000.0  3280000.0  3323519.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        410445.0   423591.0   438671.0
# Algeria                                       2503218.0  2595056.0  2713079.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
# ...

# %%
#Step 3
#Check whether both tables have the same size and shape.

#If they don’t, it is not a problem. It is just good practice to check.

print(fert.shape, life.shape, popu.shape)
# Out:
# (260, 216) (260, 217) (275, 81)

# %%
#Step 4
#Take a look at the columns of both tables:

fert.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %%
life.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#            dtype='int64', length=217)

# %%
popu.columns
# Out:
# Int64Index([1800, 1810, 1820, 1830, 1840, 1850, 1860, 1870, 1880, 1890, 1900,
#             1910, 1920, 1930, 1940, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#             1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#             1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#             1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#             1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#             2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015],
#            dtype='int64')

# %%
#One table has columns as strings, the other has integer numbers. To merge the tables, we need to convert both into the same format. First, we create a list of years as integers.

ncol = [int(x) for x in fert.columns]

#and use this list as the new columns:

fert.set_axis(axis=1, labels=ncol, inplace=True)

fert.columns
#Check with fert.columns whether the transformation was successful.
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015],
#            dtype='int64', length=216)

# %%
###Step 5
#To obtain nice column names, you can also create a hierarchical index. For that, we convert both tables to the long format:

sfert = fert.stack()
slife = life.stack()
spopu = popu.stack()

#The variables sfert and slife now have the type pd.Series. Multiple Series can be converted to a pd.DataFrame, using a dictionary with the values:

d = {'fertility': sfert, 'lifeexp': slife, 'population': spopu}
df2 = pd.DataFrame(data=d)

df2
# Out:
#                   fertility  lifeexp  population
# Afghanistan 1800        7.0    28.21   3280000.0
#             1801        7.0    28.20         NaN
#             1802        7.0    28.19         NaN
#             1803        7.0    28.18         NaN
#             1804        7.0    28.17         NaN
# ...                     ...      ...         ...
# Åland       2006        NaN    80.10     26923.0
#             2007        NaN      NaN     26923.0
#             2008        NaN      NaN     26923.0
#             2009        NaN      NaN     26923.0
#             2010        NaN      NaN     26923.0
#
# [47688 rows x 3 columns]

# %% [markdown]
# Step 6
# Repeat the steps above to add data from the file data/gapminder_population.xlsx.

# %%
popu= pd.read_excel('/Users/JoseMontero/Desktop/gapminder_population.xlsx', index_col=0)

popu
# Out:
#                                                    1800       1810       1820  \
# Total population
# Abkhazia                                            NaN        NaN        NaN
# Afghanistan                                   3280000.0  3280000.0  3323519.0
# Akrotiri and Dhekelia                               NaN        NaN        NaN
# Albania                                        410445.0   423591.0   438671.0
# Algeria                                       2503218.0  2595056.0  2713079.0
# ...                                                 ...        ...        ...
# Northern Marianas                                   NaN        NaN        NaN
# South Georgia and the South Sandwich Islands        NaN        NaN        NaN
# US Minor Outlying Islands                           NaN        NaN        NaN
# Virgin Islands                                      NaN        NaN        NaN
# West Bank                                           NaN        NaN        NaN
#
# ...

# %% [markdown]
# Step 7
# The huge DataFrame is easier to convert to the right format, if we first interpret all indices (rows and columns) as row indices:
#
# df3 = df2.stack()
# Finally we can convert the long table back to a wide one. For that we create new columns from the 1st and 3rd level of the index (the country names and attributes):
#
# df4 = df3.unstack((0,2))
# The zero stands for the first element of an index. With the value 1 all year numbers would end up as columns.
#
# Now df4 is a table, with years on the left side and life expectancy and fertility for a ll countries on top.

# %%
df3 = df2.stack()
df3
# Out:
# Afghanistan  1800  fertility           7.00
#                    lifeexp            28.21
#                    population    3280000.00
#              1801  fertility           7.00
#                    lifeexp            28.20
#                                     ...
# Åland        2006  population      26923.00
#              2007  population      26923.00
#              2008  population      26923.00
#              2009  population      26923.00
#              2010  population      26923.00
# Length: 107445, dtype: float64

# %%
df4 = df3.unstack(0,2)
df4
# Out:
#                  Afghanistan  Akrotiri and Dhekelia     Albania      Algeria  \
# 1800 fertility          7.00                    2.0        4.60         6.99
#      lifeexp           28.21                    2.0       35.40        28.82
#      population   3280000.00                    2.0   410445.00   2503218.00
# 1801 fertility          7.00                    2.0        4.60         6.99
#      lifeexp           28.20                    2.0       35.40        28.82
# ...                      ...                    ...         ...          ...
# 2014 population  31627506.00                    2.0  2889676.00  38934334.00
# 2015 fertility          4.47                    2.0        1.78         2.71
#      lifeexp           53.80                    2.0       78.00        76.40
#      population  32526562.00                    2.0  2896679.00  39666519.00
# 2016 lifeexp           52.72                    2.0       78.10        76.50
#
# ...

# %% [markdown]
# Step 8
# Now you can select specific columns and plot them:
#
# import pylab as plt
# df4[['Germany', 'France', 'Sweden']].plot()
# To create a scatterplot, we extract the columns to plot from df3:
#
# df5 = df3.unstack(2)
# df5.plot.scatter('fertility', 'lifeexp', s=0.1)
# Using stack and unstack you can also select a year. That makes the plot easier to read:
#
# df6 = df3.unstack(1)
# df6 = df6[1950]
# df6 = df6.unstack(1)
# df6.plot.scatter('fertility', 'lifeexp', s=0.1)

# %%
import pylab as plt
df4[['Germany', 'Spain', 'China', 'Chile']].plot(figsize=(12, 8))

# %%
df5 = df3.unstack(2)
df5.plot.scatter('fertility', 'lifeexp', s=0.1, figsize=(12, 8))

# %%
df6 = df3.unstack(1)
df6 = df6[1950]
df6 = df6.unstack(1)
df6.plot.scatter('fertility', 'lifeexp', s=0.1, figsize=(12, 8))

# %% [markdown]
# Step 9
# Now we can improve our graphics, e.g. color each country differently:
#
# cmap = plt.get_cmap('tab20', lut = len(df6)).colors
# df6.plot.scatter('fertility', 'lifeexp', s=0.1, c=cmap)
#
# Hint The lut parameter allows you to control the length of the color array (which by default is 20), and in the above code we ensure that it is same length as the index of our dataframe.
# or use a third column with the size of the dots:
#
# df6.plot.scatter('fertility', 'lifeexp', s=df6['population'])

# %%
cmap = plt.get_cmap('tab20', lut = len(df6)).colors
df6.plot.scatter('fertility', 'lifeexp', s=12, c=cmap, figsize=(12, 8))

# %%
#df6.plot.scatter('fertility', 'lifeexp', s=df6['population'])

plot = df6.plot.scatter('fertility', 'lifeexp', s=df6['population']/100_000, figsize=(12, 8), c=cmap)

# %% [markdown]
# Step 10
# To create an animated scatterplot showing the correlation between life expectancy and fertility, create one plot for each year between 1960 and 2015 (before that, the data contains too many gaps).
#
# Save each scatterplot to a separate file containing the year in the filename, e.g. lifeexp_1999.png .
#
# Hint Use the function plt.axis((a,b,c,d)) to fix the coordinates of the plot.
#
# startyear = 1950
# endyear=2015
# for year in np.arange(startyear,endyear,1):
#     #year = 1960
#     gdf = newdf[newdf['Year']==year]
#     maxx = newdf['MortalityRatePer1000Births'].max()+10
#     maxy = newdf['BirthRatePer1000Population'].max()+10
#     clist ={"Afghanistan":'black','Bangladesh':'orange','China':'red','India':'blue','Nepal':'purple','Pakistan':'green','Sri Lanka':'brown'}
#     bubble_linecolor = 'None'
#     legend_labels=[]
#     legend_lines=[]
#
#     fig = plt.figure()
#     ax = plt.axes()
#     ax.set_title("Mortality Vs Birth Rate per 1000 People: " + str(year), fontsize=16)
#     ax.set_xlabel("Mortality Rate", fontsize=14)
#     ax.set_ylabel("Birth Rate", fontsize=14)
#     for key in clist:
#         #bubblesize=12
#         bubblesize = 12 + (gdf.loc[gdf['Country']==key,'Population'].max()/100)
#         #bubble_linecolor = clist[key]
#         bubble_linecolor = 'skyblue'
#         cline, =plt.plot('MortalityRatePer1000Births', 'BirthRatePer1000Population', data=gdf[gdf['Country']==key], marker='o', markerfacecolor=clist[key], markersize=bubblesize, color=bubble_linecolor, linewidth=4)
#         legend_labels.append(key)
#         legend_lines.append(cline)
#
#     plt.xlim(0, maxx)
#     plt.ylim(0, maxy);
#     plt.legend(handles=legend_lines, labels=legend_labels,bbox_to_anchor=(1.04,0.5), loc="center left", borderaxespad=0)
#
#     fig.savefig('./savedfigures/' + str(year) + '.png', bbox_inches = "tight")
#     plt.close('all')

# %%
startyear = 1960
endyear = 2015
for year in np.arrange(startyear, endyear, 1):

# %%
fig = plot.get_figure()

# %%
fig.savefig("image.png")

# %%
for i in range(1960, 2016):
    df6 = df6[i]
    df6 = df6.unstack(1)
    plot = df6.plot.scatter('fertility', 'lifeexp', s=df6['population']/100000, figsize=(12, 8), c=cmap)
    fig = plot.get_figure()
    fig.savefig(i + '.png')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1960
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-263591849f22> in <module>
#       1 for i in range(1960, 2016):
# ...

# %% [markdown]
# Step 11
# Adjust the plot, so that the size of the symbols represents the population from the gapminder dataset.

# %% [markdown]
# Step 12
# Install the Python module imageio, by typing in the terminal:
#
# pip install imageio
# Adjust the following code example and execute it:
#
# import imageio
#
# images = []
#
# for i in range(0, 100):
#     filename = 'lifeexp_{}.png'.format(i)
#     images.append(imageio.imread(filename))
#
# imageio.mimsave('output.gif', images, fps=20)

# %% [markdown]
# LONG_v_WIDE

# %%
data ={'name':['Alice', 'Bob', 'Charlie'],
      'age': [12, 34, 56],
      'weight': [44, 66, 88]}
wide = pd.DataFrame(data)

# %%
pd.DataFrame(wide.stack(), columns=['values'])

# %%
pk =pd.read_csv('/Users/JoseMontero/Desktop/pokemon.csv')

pk

# %% [markdown]
# For each Pokemon Type(e.g. Grass, Fire, Ice) is there a clear increase in average attack if it is legendary?

# %%
pk2 = pk.groupby(['Type 1', 'Legendary'])[['Attack']].mean().unstack(1)

# %%
pk2['Attack'].sort_values(by=False).plot.bar()

# %%
pk

# %%
pk.groupby(['Type 1', 'Type 2'])[['Name']].count().sort_values(by='Name', ascending=False).head(10).plot.bar()

# %%
import seaborn as sns

matrix =pk.groupby(['Type 1', 'Type 2'])[['Name']].count().sort_values(by='Name', ascending=False).unstack(1)

# %%
sns.heatmap(matrix)

# %%
pk.groupby(['Type 1', 'Type 2'])['Attack'].mean().unstack(1)
